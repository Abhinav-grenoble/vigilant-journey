# %%
import matplotlib.pyplot as plt
import random
import timeit
def u_array(debug=False, N=21):
    """
    Retourne un tableau non trie avec des valeur de 1 <= i < N .
    Par defaut un tableau  1 <= i < 21
    
    Pour tester vos algorithmes, vous pouvez passer l'argument debug=True
    dans ce cas, l'algorithme vous donne toujour le meme tableau :
    
    [3, 9, 7, 1, 6, 2, 8, 4, 5]
    
    """
    array = list(range(1,N))
    if debug:
        return array
    
    
    random.shuffle(array)

    return array

# %%
def swap(A, i, j):
    """Helper function to swap elements i and j of list A."""
    i_dum=A[i]
    A[i]=A[j]
    A[j]=i_dum
    return A

# %%
def selection(A):
    """
    it will automatically update the list no need to return it.
    on cherche l'element qui doit se placer a l'i_eme place
    """
    for i in range(len(A)):
        min_fake= i
        for j in range(i+1,len(A)):
            if A[j] < A[min_fake]:
                min_fake=j
        if min_fake!= i:
            swap(A, i, min_fake) 
    


time_sel=[]
x=[]
for i in range(50, 2000, 50):
    arr=u_array(N=i)
    time_sel.append(timeit.timeit(lambda: selection(arr.copy()), number=10))
    x.append(i)
print("time diff===", x)
# Out:
# time diff=== [50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950, 1000, 1050, 1100, 1150, 1200, 1250, 1300, 1350, 1400, 1450, 1500, 1550, 1600, 1650, 1700, 1750, 1800, 1850, 1900, 1950]

# %%
x1=x
y1=time_sel



plt.plot(x1, y1, label = "sel")

plt.legend()
plt.xlabel('sample size')
plt.ylabel('time taken in  10 cycle')
plt.show()
