# %%
import matplotlib.pyplot as plt
import random
import timeit
def u_array(debug=False, N=21):
    """
    Retourne un tableau non trie avec des valeur de 1 <= i < N .
    Par defaut un tableau  1 <= i < 21
    
    Pour tester vos algorithmes, vous pouvez passer l'argument debug=True
    dans ce cas, l'algorithme vous donne toujour le meme tableau :
    
    [3, 9, 7, 1, 6, 2, 8, 4, 5]
    
    """
    array = list(range(1,N))
    if debug:
        return array
    
    
    random.shuffle(array)

    return array

# %%
def swap(A, i, j):
    """Helper function to swap elements i and j of list A."""
    i_dum=A[i]
    A[i]=A[j]
    A[j]=i_dum
    return A

# %%
def bubble(A):
    """
    les grands valeurs remontent aux derniers position du tableau
    comme des bulles d'air dans l'eau
    
    """

    for i in range(len(A),0,-1):
        for j in range(0,(i-1)):
            if A[j+1]<A[j]:
                swap(A,j,j+1)
    return A         

time_sel=[]
x=[]
time_bub=[]
for i in range(50, 2000, 50):
    arr=u_array(N=i)
    time_bub.append(timeit.timeit(lambda: bubble(arr.copy()), number=10))
    x.append(i)
print("time diff===", time_bub)
print("time diff===", x)
# Out:
# time diff=== [0.0017203439492732286, 0.006587933050468564, 0.013614987023174763, 0.02518780087120831, 0.03576925001107156, 0.04955811216495931, 0.07024032808840275, 0.09904824802652001, 0.12824174808338284, 0.15499343699775636, 0.17728495504707098, 0.22085300600156188, 0.2579524698667228, 0.37473216000944376, 0.491875140927732, 0.5058034299872816, 0.4383405379485339, 0.5987615659832954, 0.5844792479183525, 0.6347096499521285, 0.6867115318309516, 0.7900835920590907, 0.8429817438591272, 0.9105690920259804, 1.028714451007545, 1.082295838976279, 1.143899783026427, 1.2680901968851686, 1.7724769681226462, 1.756412222981453, 1.6186817141715437, 1.7804178490769118, 1.869592075003311, 2.2653378578834236, 2.25760195706971, 2.2442108569666743, 2.165048288181424, 2.885021931026131, 2.869528834009543]

# %%
x1=x
y1=time_bub



plt.plot(x1, y1, label = "sel")

plt.legend()
plt.xlabel('sample size')
plt.ylabel('time taken in  10 cycle')
plt.show()
